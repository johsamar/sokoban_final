# %%
# !pip install mesa
# !pip install pillow
# !pip install numpy
# !pip install --upgrade mesa
# !pip install ipywidgets

# %%
import model
import agent
import numpy as np

# %%
import threading

thread = threading.Thread(target=exec, args=(open("server.py").read(),))
thread.start()
# Out:
# Exception in thread Thread-15 (exec):
# Traceback (most recent call last):
#   File "C:\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 45, in <module>
#   File "c:\Users\Oscar\Desktop\sokoban_final\src\model\model.py", line 56, in __init__
#     game_state = GameState(self)
#                  ^^^^^^^^^^^^^^^
#   File "c:\Users\Oscar\Desktop\sokoban_final\src\helpers\game_state.py", line 26, in __init__
#     self.path = self.beam_search()
#                 ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Oscar\Desktop\sokoban_final\src\helpers\game_state.py", line 215, in beam_search
#     self.save_game_state(f"states/node_{current_state['nodo']}.txt")
#   File "c:\Users\Oscar\Desktop\sokoban_final\src\helpers\game_state.py", line 85, in save_game_state
#     write_files(filename, lines)
# ...
